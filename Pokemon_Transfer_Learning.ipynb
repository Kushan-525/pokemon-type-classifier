# %%
# --- Bibliotecas Estándar de Python ---
import os
import pickle
import random
from collections import Counter

# --- Bibliotecas de Ciencia de Datos y Gráficos ---
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# --- TensorFlow (Núcleo) ---
import tensorflow as tf

# --- Utilidades de Scikit-learn ---
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

# --- TensorFlow Keras (Modelos y Aplicaciones) ---
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import ResNet50

# --- TensorFlow Keras (Capas) ---
# (Se incluyen las capas de Aumento de Datos de la celda 11)
from tensorflow.keras.layers import (
    Input, Dense, Dropout,
    GlobalAveragePooling2D, RandomFlip,
    RandomRotation, RandomZoom
)

# --- TensorFlow Keras (Componentes de Entrenamiento) ---
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ruta
path_pokemon = '/content/drive/MyDrive/Colab Notebooks/Pokemon/Datos/pokemonDB_dataset.csv'

# Carga de datos
df = pd.read_csv(path_pokemon)

# Dividir los tipos múltiples en listas
listas_de_tipos = df['Type'].str.split(',')

conteo_tipos = Counter()

for lista in listas_de_tipos:
        # Creamos una lista limpia para cada Pokémon
        tipos_limpios = []
        for tipo in lista:
            # .strip() elimina espacios en blanco al inicio o final
            # ej. " Ice" -> "Ice"
            tipos_limpios.append(tipo.strip())

        # Actualizamos el conteo con los tipos limpios
        conteo_tipos.update(tipos_limpios)

# %%
#---------------------------------------------------------------------------------------------------------------

if not os.path.exists("/content/pokemon1"):
  print("Copiando dataset de Drive a Colab...")
  # !cp "/content/drive/MyDrive/Colab Notebooks/Pokemon/Datos/Pokemon Images DB.zip" "/content/pokemon1.zip"
  print("¡Copia finalizada!")

  print("Descomprimiendo dataset...")
  # !unzip -q /content/pokemon1.zip -d /content/pokemon1
  print("¡Dataset listo en /content/pokemon1!")
else:
  print("El dataset ya está en /content/pokemon1")

#---------------------------------------------------------------------------------------------------------------

if not os.path.exists("/content/pokemon2"):
  print("Copiando dataset de Drive a Colab...")
  # !cp "/content/drive/MyDrive/Colab Notebooks/Pokemon/Datos/Pokemon Dataset.zip" "/content/pokemon2.zip"
  print("¡Copia finalizada!")

  print("Descomprimiendo dataset...")
  # !unzip -q /content/pokemon2.zip -d /content/pokemon2
  print("¡Dataset listo en /content/pokemon2!")
else:
  print("El dataset ya está en /content/pokemon2")

#---------------------------------------------------------------------------------------------------------------

if not os.path.exists("/content/pokemon3"):
  print("Copiando dataset de Drive a Colab...")
  # !cp "/content/drive/MyDrive/Colab Notebooks/Pokemon/Datos/Fotos Pokemon1.zip" "/content/pokemon3.zip"
  print("¡Copia finalizada!")

  print("Descomprimiendo dataset...")
  # !unzip -q /content/pokemon3.zip -d /content/pokemon3
  print("¡Dataset listo en /content/pokemon3!")
else:
  print("El dataset ya está en /content/pokemon3")

#---------------------------------------------------------------------------------------------------------------
# Out:
# Copiando dataset de Drive a Colab...
# ¡Copia finalizada!
# Descomprimiendo dataset...
# ¡Dataset listo en /content/pokemon1!
# Copiando dataset de Drive a Colab...
# ¡Copia finalizada!
# Descomprimiendo dataset...
# ¡Dataset listo en /content/pokemon2!
# Copiando dataset de Drive a Colab...
# ¡Copia finalizada!
# Descomprimiendo dataset...
# ¡Dataset listo en /content/pokemon3!

# %%
def normalize_name(name):
    """
    Limpia un nombre de Pokémon para que coincida
    entre el CSV y los nombres de las carpetas.
    """
    if not isinstance(name, str):
        name = str(name)

    # Convertir a minúsculas PRIMERO
    name = name.lower()

    # 2. Quitar paréntesis y espacios
    name = name.replace("(", "").replace(")", "")

    # 3. Reemplazar caracteres especiales
    name = name.replace('♀', '-f')       # nidoran♀ -> nidoran-f
    name = name.replace('♂', '-m')       # nidoran♂ -> nidoran-m
    name = name.replace("'", "")       # farfetch'd -> farfetchd
    name = name.replace(".", "")       # mime jr. -> mimejr
    name = name.replace("_", "-")      # farfetch_d -> farfetch-d
    name = name.replace(" ", "")       # Mime Jr. -> mimejr (manejado por .lower() y replace)
    name = name.replace(":", "")       # Type: Null -> typenull

    return name

    print("Creando mapa de etiquetas normalizado...")

label_map = {}

for index, row in df.iterrows():

    # Obtener el nombre "sucio" del CSV
    nombre_pokemon_csv = row['Pokemon']

    # Manejar los casos especiales de Nidoran

    if "Nidoran♀ (female)" in nombre_pokemon_csv:
        nombre_a_normalizar = "Nidoran♀"
    elif "Nidoran♂ (male)" in nombre_pokemon_csv:
        nombre_a_normalizar = "Nidoran♂"
    else:
        # Si no es un caso especial, usar el nombre tal cual
        nombre_a_normalizar = nombre_pokemon_csv

    # 1. Normalizar el nombre (ya sea el original o el pre-limpiado)
    nombre_normalizado = normalize_name(nombre_a_normalizar)

    # 2. Obtener los tipos
    tipos_str = row['Type']
    lista_de_tipos = [tipo.strip() for tipo in tipos_str.split(',')]

    # 3. Guardar en el mapa con la clave normalizada
    if nombre_normalizado not in label_map:
        label_map[nombre_normalizado] = lista_de_tipos
    else:
        pass

print(f"--- Mapa de Etiquetas Creado. {len(label_map)} entradas únicas. ---")

# (Opcional) Verifica que los nombres clave se normalizaron bien
print("\nEjemplo del mapa (normalizado):")
print(f"'nidoran-f': {label_map.get('nidoran-f')}")
print(f"'nidoran-m': {label_map.get('nidoran-m')}")
print(f"'aegislashbladeforme': {label_map.get('aegislashbladeforme')}")
print(f"'farfetchd': {label_map.get('farfetchd')}")
print(f"'mimejr': {label_map.get('mimejr')}")
# Out:
# --- Mapa de Etiquetas Creado. 1215 entradas únicas. ---
#
# Ejemplo del mapa (normalizado):
# 'nidoran-f': ['Poison']
# 'nidoran-m': ['Poison']
# 'aegislashbladeforme': ['Steel', 'Ghost']
# 'farfetchd': ['Normal', 'Flying']
# 'mimejr': ['Psychic', 'Fairy']

# %%
carpeta_raiz = '/content/pokemon1'
X_rutas_imagenes = []
y_etiquetas = []

print("\nIniciando exploración.")

for root, dirs, files in os.walk(carpeta_raiz):

    if root == carpeta_raiz:
        continue

    # 1. Obtener el nombre de la carpeta
    nombre_pokemon_folder = os.path.basename(root)

    # 2. ¡Normalizar el nombre de la carpeta con la MISMA función!
    nombre_normalizado = normalize_name(nombre_pokemon_folder)

    # 3. Buscar el nombre NORMALIZADO en nuestro mapa NORMALIZADO
    if nombre_normalizado in label_map:
        for file_name in files:
            if file_name.endswith(('.png', '.jpg', '.jpeg')):
                ruta_completa = os.path.join(root, file_name)
                X_rutas_imagenes.append(ruta_completa)
                y_etiquetas.append(label_map[nombre_normalizado])
    else:
        # Si esto se imprime, es un Pokémon que REALMENTE falta
        print(f"Advertencia: Carpeta '{nombre_pokemon_folder}' (normalizado a '{nombre_normalizado}') no encontrada en el CSV.")

print("\n" + "-"*60)
print("Rutas de imágenes y etiquetas recopiladas con éxito.")
print(f"Total de imágenes encontradas: {len(X_rutas_imagenes)}")
print(f"Total de etiquetas recopiladas: {len(y_etiquetas)}")
print("-"*60 + "\n")

# --- Verificación Rápida ---
if len(X_rutas_imagenes) > 0:
    print("Ejemplo de datos recopilados:")
    print(f"Ruta: {X_rutas_imagenes[0]}")
    print(f"Etiqueta: {y_etiquetas[0]}")
else:
    print("¡Advertencia! No se encontró ninguna imagen. Revisa la 'carpeta_raiz' y los nombres en el CSV.")

carpeta_raiz_nueva = r'/content/pokemon2'

print(f"\nIniciando exploración de la segunda fuente de datos: {carpeta_raiz_nueva}...")
imagenes_encontradas_antes = len(X_rutas_imagenes)

# Usamos os.walk para explorar la nueva ruta
for root, dirs, files in os.walk(carpeta_raiz_nueva):

    # 2. Filtrar: Buscamos carpetas que sean 'normal' y no 'shiny'
    #    Usamos .lower() para encontrar 'normal' o 'Normal'
    if os.path.sep + 'normal' in root.lower() and 'shiny' not in root.lower():

        # 3. Extraer el nombre del Pokémon
        try:
            partes_ruta = root.split(os.path.sep)

            # La carpeta 'normal' es la de [version]
            # La ruta es: ...\[nombrepokemon]\[generacion]\[juego]\[version]
            # Por lo tanto, el nombre está 3 niveles "arriba" de 'normal'

            # Encontramos el índice de la carpeta 'normal' (o 'Normal')
            idx_normal = -1
            for i, parte in enumerate(partes_ruta):
                if parte.lower() == 'normal':
                    idx_normal = i
                    break

            if idx_normal != -1 and idx_normal >= 3:
                # Extraemos el nombre: [idx_normal - 3]
                nombre_pokemon_folder = partes_ruta[idx_normal - 3]

                # 4. Normalizar el nombre (¡usando la misma función!)
                nombre_normalizado = normalize_name(nombre_pokemon_folder)

                # 5. Buscar en el mapa y añadir
                if nombre_normalizado in label_map:
                    for file_name in files:
                        # Nos aseguramos de tomar solo PNGs/JPGs (NO GIFs)
                        if file_name.endswith(('.png', '.jpg', '.jpeg')):
                            ruta_completa = os.path.join(root, file_name)
                            X_rutas_imagenes.append(ruta_completa)
                            y_etiquetas.append(label_map[nombre_normalizado])
                else:
                    # (Nos avisará si este nombre de carpeta no está en el CSV)
                    print(f"Advertencia (Fuente 2): Carpeta '{nombre_pokemon_folder}' (normalizado a '{nombre_normalizado}') no encontrada.")

        except Exception as e:
            print(f"Error procesando ruta {root}: {e}")

print("\n" + "-"*60)
print("Exploración de la segunda fuente de datos completada.")
nuevas_imagenes = len(X_rutas_imagenes) - imagenes_encontradas_antes
print(f"Imágenes añadidas desde esta fuente: {nuevas_imagenes}")
print(f"TOTAL de imágenes encontradas (ambas fuentes): {len(X_rutas_imagenes)}")
print(f"TOTAL de etiquetas recopiladas: {len(y_etiquetas)}")
print("-"*60 + "\n")



carpeta_raiz = '/content/pokemon3'

print("\nIniciando exploración.")

for root, dirs, files in os.walk(carpeta_raiz):

    if root == carpeta_raiz:
        continue

    # 1. Obtener el nombre de la carpeta
    nombre_pokemon_folder = os.path.basename(root)

    # 2. ¡Normalizar el nombre de la carpeta con la MISMA función!
    nombre_normalizado = normalize_name(nombre_pokemon_folder)

    # 3. Buscar el nombre NORMALIZADO en nuestro mapa NORMALIZADO
    if nombre_normalizado in label_map:
        for file_name in files:
            if file_name.endswith(('.png', '.jpg', '.jpeg')):
                ruta_completa = os.path.join(root, file_name)
                X_rutas_imagenes.append(ruta_completa)
                y_etiquetas.append(label_map[nombre_normalizado])
    else:
        # Si esto se imprime, es un Pokémon que REALMENTE falta
        print(f"Advertencia: Carpeta '{nombre_pokemon_folder}' (normalizado a '{nombre_normalizado}') no encontrada en el CSV.")

print("\n" + "-"*60)
print("Rutas de imágenes y etiquetas recopiladas con éxito.")
print(f"Total de imágenes encontradas: {len(X_rutas_imagenes)}")
print(f"Total de etiquetas recopiladas: {len(y_etiquetas)}")
print("-"*60 + "\n")

# --- Verificación Rápida ---
if len(X_rutas_imagenes) > 0:
    print("Ejemplo de datos recopilados:")
    print(f"Ruta: {X_rutas_imagenes[0]}")
    print(f"Etiqueta: {y_etiquetas[0]}")
else:
    print("¡Advertencia! No se encontró ninguna imagen. Revisa la 'carpeta_raiz' y los nombres en el CSV.")
# Out:
# Iniciando exploración.
# Advertencia: Carpeta 'Pokemon Images DB' (normalizado a 'pokemonimagesdb') no encontrada en el CSV.
# Advertencia: Carpeta 'Hoopa (Hoopa Unbound)' (normalizado a 'hoopahoopaunbound') no encontrada en el CSV.
# Advertencia: Carpeta 'Sirfetch_d' (normalizado a 'sirfetch-d') no encontrada en el CSV.
# Advertencia: Carpeta 'Eevee (Partner Eevee)' (normalizado a 'eeveepartnereevee') no encontrada en el CSV.
# Advertencia: Carpeta 'Necrozma (Dawn Wings Necrozma)' (normalizado a 'necrozmadawnwingsnecrozma') no encontrada en el CSV.
# Advertencia: Carpeta 'Oricorio (Pa_u Style)' (normalizado a 'oricoriopa-ustyle') no encontrada en el CSV.
# Advertencia: Carpeta 'Necrozma (Ultra Necrozma)' (normalizado a 'necrozmaultranecrozma') no encontrada en el CSV.
# Advertencia: Carpeta 'Zygarde (10_ Forme)' (normalizado a 'zygarde10-forme') no encontrada en el CSV.
# Advertencia: Carpeta 'Pikachu (Partner Pikachu)' (normalizado a 'pikachupartnerpikachu') no encontrada en el CSV.
# Advertencia: Carpeta 'Necrozma (Dusk Mane Necrozma)' (normalizado a 'necrozmaduskmanenecrozma') no encontrada en el CSV.
# Advertencia: Carpeta 'Greninja (Ash-Greninja)' (normalizado a 'greninjaash-greninja') no encontrada en el CSV.
# Advertencia: Carpeta 'Rotom (Wash Rotom)' (normalizado a 'rotomwashrotom') no encontrada en el CSV.
# Advertencia: Carpeta 'Rotom (Heat Rotom)' (normalizado a 'rotomheatrotom') no encontrada en el CSV.
# Advertencia: Carpeta 'Kyurem (Black Kyurem)' (normalizado a 'kyuremblackkyurem') no encontrada en el CSV.
# Advertencia: Carpeta 'Farfetch_d' (normalizado a 'farfetch-d') no encontrada en el CSV.
# Advertencia: Carpeta 'Hoopa (Hoopa Confined)' (normalizado a 'hoopahoopaconfined') no encontrada en el CSV.
# Advertencia: Carpeta 'Galarian Farfetch_d' (normalizado a 'galarianfarfetch-d') no encontrada en el CSV.
# Advertencia: Carpeta 'Rotom (Frost Rotom)' (normalizado a 'rotomfrostrotom') no encontrada en el CSV.
# Advertencia: Carpeta 'Rotom (Fan Rotom)' (normalizado a 'rotomfanrotom') no encontrada en el CSV.
# Advertencia: Carpeta 'Zygarde (50_ Forme)' (normalizado a 'zygarde50-forme') no encontrada en el CSV.
# Advertencia: Carpeta 'Rotom (Mow Rotom)' (normalizado a 'rotommowrotom') no encontrada en el CSV.
# Advertencia: Carpeta 'Kyurem (White Kyurem)' (normalizado a 'kyuremwhitekyurem') no encontrada en el CSV.
#
# ------------------------------------------------------------
# Rutas de imágenes y etiquetas recopiladas con éxito.
# Total de imágenes encontradas: 2332
# Total de etiquetas recopiladas: 2332
# ------------------------------------------------------------
#
# Ejemplo de datos recopilados:
# Ruta: /content/pokemon1/Pokemon Images DB/Galarian Linoone/Galarian Linoone_new.png
# Etiqueta: ['Dark', 'Normal']
#
# Iniciando exploración de la segunda fuente de datos: /content/pokemon2...
# Advertencia (Fuente 2): Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Urshifu' (normalizado a 'urshifu') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Urshifu' (normalizado a 'urshifu') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Urshifu' (normalizado a 'urshifu') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Pumpkaboo' (normalizado a 'pumpkaboo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Pumpkaboo' (normalizado a 'pumpkaboo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Pumpkaboo' (normalizado a 'pumpkaboo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Pumpkaboo' (normalizado a 'pumpkaboo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Pumpkaboo' (normalizado a 'pumpkaboo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Pumpkaboo' (normalizado a 'pumpkaboo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tatsugiri' (normalizado a 'tatsugiri') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Ogerpon' (normalizado a 'ogerpon') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Morpeko' (normalizado a 'morpeko') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Morpeko' (normalizado a 'morpeko') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Morpeko' (normalizado a 'morpeko') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Maushold' (normalizado a 'maushold') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Aegislash' (normalizado a 'aegislash') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Aegislash' (normalizado a 'aegislash') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Aegislash' (normalizado a 'aegislash') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Aegislash' (normalizado a 'aegislash') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Aegislash' (normalizado a 'aegislash') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Aegislash' (normalizado a 'aegislash') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculin' (normalizado a 'basculin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Terapagos' (normalizado a 'terapagos') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Minior' (normalizado a 'minior') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Minior' (normalizado a 'minior') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Minior' (normalizado a 'minior') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Minior' (normalizado a 'minior') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Dudunsparce' (normalizado a 'dudunsparce') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gourgeist' (normalizado a 'gourgeist') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gourgeist' (normalizado a 'gourgeist') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gourgeist' (normalizado a 'gourgeist') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gourgeist' (normalizado a 'gourgeist') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gourgeist' (normalizado a 'gourgeist') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gourgeist' (normalizado a 'gourgeist') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Palafin' (normalizado a 'palafin') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wishiwashi' (normalizado a 'wishiwashi') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wishiwashi' (normalizado a 'wishiwashi') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wishiwashi' (normalizado a 'wishiwashi') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wishiwashi' (normalizado a 'wishiwashi') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Wishiwashi' (normalizado a 'wishiwashi') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Indeedee' (normalizado a 'indeedee') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Indeedee' (normalizado a 'indeedee') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Indeedee' (normalizado a 'indeedee') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zygarde' (normalizado a 'zygarde') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zygarde' (normalizado a 'zygarde') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zygarde' (normalizado a 'zygarde') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zygarde' (normalizado a 'zygarde') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zygarde' (normalizado a 'zygarde') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zygarde' (normalizado a 'zygarde') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Enamorus' (normalizado a 'enamorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Enamorus' (normalizado a 'enamorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Enamorus' (normalizado a 'enamorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Eiscue' (normalizado a 'eiscue') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Eiscue' (normalizado a 'eiscue') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Eiscue' (normalizado a 'eiscue') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Burmy' (normalizado a 'burmy') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gimmighoul' (normalizado a 'gimmighoul') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Gimmighoul' (normalizado a 'gimmighoul') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Squawkabilly' (normalizado a 'squawkabilly') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zacian' (normalizado a 'zacian') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zacian' (normalizado a 'zacian') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zacian' (normalizado a 'zacian') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zacian' (normalizado a 'zacian') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zamazenta' (normalizado a 'zamazenta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zamazenta' (normalizado a 'zamazenta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zamazenta' (normalizado a 'zamazenta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Zamazenta' (normalizado a 'zamazenta') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Giratina' (normalizado a 'giratina') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Oricorio' (normalizado a 'oricorio') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Oricorio' (normalizado a 'oricorio') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Oricorio' (normalizado a 'oricorio') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Oricorio' (normalizado a 'oricorio') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Oricorio' (normalizado a 'oricorio') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Oinkologne' (normalizado a 'oinkologne') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Oinkologne' (normalizado a 'oinkologne') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculegion' (normalizado a 'basculegion') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculegion' (normalizado a 'basculegion') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Basculegion' (normalizado a 'basculegion') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Hoopa' (normalizado a 'hoopa') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Hoopa' (normalizado a 'hoopa') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Hoopa' (normalizado a 'hoopa') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Hoopa' (normalizado a 'hoopa') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Hoopa' (normalizado a 'hoopa') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Hoopa' (normalizado a 'hoopa') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Toxtricity' (normalizado a 'toxtricity') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Toxtricity' (normalizado a 'toxtricity') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Toxtricity' (normalizado a 'toxtricity') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
# Advertencia (Fuente 2): Carpeta 'Landorus' (normalizado a 'landorus') no encontrada.
#
# ------------------------------------------------------------
# Exploración de la segunda fuente de datos completada.
# Imágenes añadidas desde esta fuente: 10380
# TOTAL de imágenes encontradas (ambas fuentes): 12712
# TOTAL de etiquetas recopiladas: 12712
# ------------------------------------------------------------
#
#
# Iniciando exploración.
# Advertencia: Carpeta 'Fotos Pokemon1' (normalizado a 'fotospokemon1') no encontrada en el CSV.
# Advertencia: Carpeta 'images' (normalizado a 'images') no encontrada en el CSV.
# Advertencia: Carpeta 'Meowstic' (normalizado a 'meowstic') no encontrada en el CSV.
# Advertencia: Carpeta 'Urshifu' (normalizado a 'urshifu') no encontrada en el CSV.
# Advertencia: Carpeta 'Darmanitan' (normalizado a 'darmanitan') no encontrada en el CSV.
# Advertencia: Carpeta 'Pumpkaboo' (normalizado a 'pumpkaboo') no encontrada en el CSV.
# Advertencia: Carpeta 'Deoxys' (normalizado a 'deoxys') no encontrada en el CSV.
# Advertencia: Carpeta 'Sirfetch_d' (normalizado a 'sirfetch-d') no encontrada en el CSV.
# Advertencia: Carpeta 'Wormadam' (normalizado a 'wormadam') no encontrada en el CSV.
# Advertencia: Carpeta 'Flab├®b├®' (normalizado a 'flab├®b├®') no encontrada en el CSV.
# Advertencia: Carpeta 'Keldeo' (normalizado a 'keldeo') no encontrada en el CSV.
# Advertencia: Carpeta 'Shaymin' (normalizado a 'shaymin') no encontrada en el CSV.
# Advertencia: Carpeta 'Morpeko' (normalizado a 'morpeko') no encontrada en el CSV.
# Advertencia: Carpeta 'Aegislash' (normalizado a 'aegislash') no encontrada en el CSV.
# Advertencia: Carpeta 'Basculin' (normalizado a 'basculin') no encontrada en el CSV.
# Advertencia: Carpeta 'Thundurus' (normalizado a 'thundurus') no encontrada en el CSV.
# Advertencia: Carpeta 'Minior' (normalizado a 'minior') no encontrada en el CSV.
# Advertencia: Carpeta 'Gourgeist' (normalizado a 'gourgeist') no encontrada en el CSV.
# Advertencia: Carpeta 'Wishiwashi' (normalizado a 'wishiwashi') no encontrada en el CSV.
# Advertencia: Carpeta 'Indeedee' (normalizado a 'indeedee') no encontrada en el CSV.
# Advertencia: Carpeta 'Zygarde' (normalizado a 'zygarde') no encontrada en el CSV.
# Advertencia: Carpeta 'Farfetch_d' (normalizado a 'farfetch-d') no encontrada en el CSV.
# Advertencia: Carpeta 'Lycanroc' (normalizado a 'lycanroc') no encontrada en el CSV.
# Advertencia: Carpeta 'NidoranÔÖé' (normalizado a 'nidoranôöé') no encontrada en el CSV.
# Advertencia: Carpeta 'Eiscue' (normalizado a 'eiscue') no encontrada en el CSV.
# Advertencia: Carpeta 'Burmy' (normalizado a 'burmy') no encontrada en el CSV.
# Advertencia: Carpeta 'Meloetta' (normalizado a 'meloetta') no encontrada en el CSV.
# Advertencia: Carpeta 'NidoranÔÖÇ' (normalizado a 'nidoranôöç') no encontrada en el CSV.
# Advertencia: Carpeta 'Zacian' (normalizado a 'zacian') no encontrada en el CSV.
# Advertencia: Carpeta 'Zamazenta' (normalizado a 'zamazenta') no encontrada en el CSV.
# Advertencia: Carpeta 'Giratina' (normalizado a 'giratina') no encontrada en el CSV.
# Advertencia: Carpeta 'Oricorio' (normalizado a 'oricorio') no encontrada en el CSV.
# Advertencia: Carpeta 'Tornadus' (normalizado a 'tornadus') no encontrada en el CSV.
# Advertencia: Carpeta 'Hoopa' (normalizado a 'hoopa') no encontrada en el CSV.
# Advertencia: Carpeta 'Toxtricity' (normalizado a 'toxtricity') no encontrada en el CSV.
# Advertencia: Carpeta 'Landorus' (normalizado a 'landorus') no encontrada en el CSV.
#
# ------------------------------------------------------------
# Rutas de imágenes y etiquetas recopiladas con éxito.
# Total de imágenes encontradas: 15068
# Total de etiquetas recopiladas: 15068
# ------------------------------------------------------------
#
# Ejemplo de datos recopilados:
# Ruta: /content/pokemon1/Pokemon Images DB/Galarian Linoone/Galarian Linoone_new.png
# Etiqueta: ['Dark', 'Normal']

# %%
print("Iniciando binarización de las 15,068 etiquetas...")

mlb = MultiLabelBinarizer()
y_binarized = mlb.fit_transform(y_etiquetas)

classes = mlb.classes_
num_classes = len(classes)

print("\n--- Binarizador de Etiquetas Creado ---")
print(f"Número total de clases (tipos) únicas: {num_classes}")
print(f"Clases encontradas: {classes}")

with open('mlb_binarizer.pkl', 'wb') as f:
    pickle.dump(mlb, f)
print("\nBinarizador guardado como 'mlb_binarizer.pkl'")
# Out:
# Iniciando binarización de las 15,032 etiquetas...
#
# --- Binarizador de Etiquetas Creado ---
# Número total de clases (tipos) únicas: 18
# Clases encontradas: ['Bug' 'Dark' 'Dragon' 'Electric' 'Fairy' 'Fighting' 'Fire' 'Flying'
#  'Ghost' 'Grass' 'Ground' 'Ice' 'Normal' 'Poison' 'Psychic' 'Rock' 'Steel'
#  'Water']
#
# Binarizador guardado como 'mlb_binarizer.pkl'

# %%
print("\nDividiendo los 15,032 items en Train/Validation...")

X_train_paths, X_val_paths, y_train, y_val = train_test_split(
    X_rutas_imagenes,
    y_binarized,
    test_size=0.2,
    random_state=42
)

print("\n--- Datos Divididos (Nuevos Totales) ---")
print(f"Imágenes de Entrenamiento (X_train_paths): {len(X_train_paths)}")
print(f"Etiquetas de Entrenamiento (y_train):     {len(y_train)}")
print(f"Imágenes de Validación (X_val_paths):   {len(X_val_paths)}")
print(f"Etiquetas de Validación (y_val):       {len(y_val)}")
# Out:
# Dividiendo los 15,032 items en Train/Validation...
#
# --- Datos Divididos (Nuevos Totales) ---
# Imágenes de Entrenamiento (X_train_paths): 12054
# Etiquetas de Entrenamiento (y_train):     12054
# Imágenes de Validación (X_val_paths):   3014
# Etiquetas de Validación (y_val):       3014

# %%
IMG_SIZE = 64
NUM_CLASSES = 18
BATCH_SIZE = 16

IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
AUTOTUNE = tf.data.AUTOTUNE

def load_and_preprocess(path, label, augment=False):
    image = tf.io.read_file(path)
    image = tf.io.decode_image(image, channels=3, expand_animations=False)
    image.set_shape([None, None, 3])

    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])

    # Normalizar
    image = image / 255.0

    return image, label

    plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    img_path = X_train_paths[i]
    label = y_train[i]

    image, _ = load_and_preprocess(img_path, label, augment=True)
    plt.imshow(image.numpy())

    tipos_pokemon = [classes[idx] for idx, val in enumerate(label) if val == 1]
    plt.title(", ".join(tipos_pokemon))
    plt.axis("off")
plt.suptitle("Ejemplos de Imágenes", fontsize=16)
plt.show()

# %%
# --- Pipeline de Entrenamiento ---
train_ds = tf.data.Dataset.from_tensor_slices((X_train_paths, y_train))
train_ds = train_ds.map(
    lambda x, y: load_and_preprocess(x, y, augment=True),
    num_parallel_calls=AUTOTUNE
)
train_ds = train_ds.shuffle(buffer_size=len(X_train_paths))
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

# --- Pipeline de Validación ---
val_ds = tf.data.Dataset.from_tensor_slices((X_val_paths, y_val))
val_ds = val_ds.map(
    lambda x, y: load_and_preprocess(x, y, augment=False),
    num_parallel_calls=AUTOTUNE
)
val_ds = val_ds.batch(BATCH_SIZE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

print("✅ Pipelines de Entrenamiento (train_ds) y Validación (val_ds) creados.")
print(f"   -> train_ds: {train_ds}")
print(f"   -> val_ds:   {val_ds}")
print("✅ Funciones de Transfer Learning listas.")
# Out:
# ✅ Pipelines de Entrenamiento (train_ds) y Validación (val_ds) creados.
#    -> train_ds: <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 18), dtype=tf.int64, name=None))>
#    -> val_ds:   <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 18), dtype=tf.int64, name=None))>
# ✅ Funciones de Transfer Learning listas.

# %%
data_augmentation = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.1), # Rotación de 10%
    RandomZoom(0.1),     # Zoom de 10%
], name='data_augmentation')


print("✅ Funciones de Transfer Learning listas.")

def create_transfer_model(input_shape, classes):
    """
    Crea un modelo ResNet-50 usando Transfer Learning.
    """
    base_model = ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape
    )

    # --- 2. Congelar la Base (Inicialmente) ---
    base_model.trainable = False # Congelamos la base SÓLO para la primera fase

    print(f"Base del modelo (ResNet-50) cargada y congelada.")
    print(f"Parámetros de la base (congelados): {base_model.count_params()}")

    # --- 3. Añadir nuestra "Cabeza" (Head) ---
    inputs = Input(shape=input_shape, name='input_layer')

    # Añadir aumento de datos
    x = data_augmentation(inputs)

    # La base del modelo (en modo inferencia por el trainable=False)
    x = base_model(x, training=False)

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5, name='head_dropout')(x)
    outputs = Dense(
        num_classes,
        activation='sigmoid',
        name='fc_pokemon'
    )(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model, base_model
# Out:
# ✅ Funciones de Transfer Learning listas.

# %%
# Crear el modelo. Ahora devuelve el modelo y la base
model, base_model = create_transfer_model(input_shape=IMG_SHAPE, classes=NUM_CLASSES)

# Compilar para la FASE 1
model.compile(optimizer=Adam(learning_rate=1e-3), # Optimizador Adam normal
              loss='binary_crossentropy',
              metrics=[
                  BinaryAccuracy(name='accuracy'),
                  Precision(name='precition'),
                  Recall(name='recall')
              ])

# Callbacks
early_stopping = EarlyStopping(
    monitor='recall',
    patience=20,
    verbose=1,
    restore_best_weights=True
)
callbacks_list = [early_stopping]

print("✅ Modelo compilado para FASE 1 (Entrenando la cabeza).")
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Base del modelo (ResNet-50) cargada y congelada.
# Parámetros de la base (congelados): 23587712
# ✅ Modelo compilado para FASE 1 (Entrenando la cabeza).
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 2, 2, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ avg_pool                        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ head_dropout (Dropout)          │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_pokemon (Dense)              │ (None, 18)             │        36,882 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,624,594 (90.12 MB)
#  Trainable params: 36,882 (144.07 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
print("--- INICIANDO FASE 1: ENTRENANDO LA CABEZA ---")
# Entrenamos solo la cabeza por unas épocas
history_fase1 = model.fit(
    train_ds,
    epochs=25, # Entrena la cabeza por 25 épocas o hasta que pare
    validation_data=val_ds,
    callbacks=callbacks_list
)

print("\n--- INICIANDO FASE 2: FINE-TUNING ---")

# --- Descongelar el modelo base ---
base_model.trainable = True

# Vamos a congelar las primeras capas y entrenar solo las superiores.
# ResNet50 tiene 175 capas. Congelemos las primeras 140.
fine_tune_at = 140
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

print(f"Descongelando modelo base desde la capa {fine_tune_at}.")

# --- Re-compilar el modelo ---
# Es CRUCIAL usar un learning rate MUY bajo para fine-tuning.
model.compile(optimizer=Adam(learning_rate=1e-5), # MUCHO MÁS BAJO
              loss='binary_crossentropy',
              metrics=[
                  BinaryAccuracy(name='accuracy'),
                  Precision(name='precition'),
                  Recall(name='recall')
              ])

print("✅ Modelo re-compilado para FASE 2 (Fine-Tuning).")

# --- Continuar el entrenamiento ---
# Entrenamos por más épocas (o hasta que el Early Stopping actúe)
history_fase2 = model.fit(
    train_ds,
    epochs=300, # Continuamos hasta 100 épocas en total
    initial_epoch=history_fase1.epoch[-1], # Empezamos desde donde se quedó la Fase 1
    validation_data=val_ds,
    callbacks=callbacks_list
)

print("🚀 ¡Entrenamiento completado (Fase 1 y 2)!")
# Out:
# --- INICIANDO FASE 1: ENTRENANDO LA CABEZA ---
# Epoch 1/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 69s 35ms/step - accuracy: 0.8866 - loss: 0.3376 - precition: 0.0838 - recall: 0.0367 - val_accuracy: 0.9169 - val_loss: 0.2802 - val_precition: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9170 - loss: 0.2841 - precition: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9169 - val_loss: 0.2784 - val_precition: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9170 - loss: 0.2829 - precition: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9169 - val_loss: 0.2779 - val_precition: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 35s 23ms/step - accuracy: 0.9172 - loss: 0.2809 - precition: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.9169 - val_loss: 0.2780 - val_precition: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 33s 25ms/step - accuracy: 0.9172 - loss: 0.2807 - precition: 0.2570 - recall: 1.6459e-05 - val_accuracy: 0.9169 - val_loss: 0.2772 - val_precition: 1.0000 - val_recall: 2.2183e-04
# Epoch 6/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 41s 25ms/step - accuracy: 0.9170 - loss: 0.2814 - precition: 0.2947 - recall: 1.3531e-04 - val_accuracy: 0.9169 - val_loss: 0.2764 - val_precition: 1.0000 - val_recall: 2.2183e-04
# Epoch 7/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 33s 24ms/step - accuracy: 0.9172 - loss: 0.2807 - precition: 0.6411 - recall: 8.9786e-05 - val_accuracy: 0.9169 - val_loss: 0.2773 - val_precition: 0.5000 - val_recall: 2.2183e-04
# Epoch 8/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 34s 25ms/step - accuracy: 0.9174 - loss: 0.2801 - precition: 0.2025 - recall: 8.8793e-05 - val_accuracy: 0.9169 - val_loss: 0.2759 - val_precition: 1.0000 - val_recall: 2.2183e-04
# Epoch 9/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9172 - loss: 0.2793 - precition: 0.2975 - recall: 1.2768e-04 - val_accuracy: 0.9169 - val_loss: 0.2762 - val_precition: 1.0000 - val_recall: 2.2183e-04
# Epoch 10/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9172 - loss: 0.2793 - precition: 0.1194 - recall: 2.2101e-05 - val_accuracy: 0.9169 - val_loss: 0.2750 - val_precition: 1.0000 - val_recall: 2.2183e-04
# Epoch 11/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9170 - loss: 0.2799 - precition: 0.5627 - recall: 3.8130e-04 - val_accuracy: 0.9169 - val_loss: 0.2762 - val_precition: 1.0000 - val_recall: 4.4366e-04
# Epoch 12/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9172 - loss: 0.2792 - precition: 0.6064 - recall: 2.5419e-04 - val_accuracy: 0.9169 - val_loss: 0.2763 - val_precition: 0.3333 - val_recall: 2.2183e-04
# Epoch 13/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 37s 31ms/step - accuracy: 0.9166 - loss: 0.2804 - precition: 0.2396 - recall: 1.4920e-04 - val_accuracy: 0.9169 - val_loss: 0.2765 - val_precition: 1.0000 - val_recall: 2.2183e-04
# Epoch 14/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 37s 31ms/step - accuracy: 0.9172 - loss: 0.2784 - precition: 0.2887 - recall: 2.4025e-04 - val_accuracy: 0.9169 - val_loss: 0.2761 - val_precition: 1.0000 - val_recall: 4.4366e-04
# Epoch 15/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9168 - loss: 0.2799 - precition: 0.4784 - recall: 3.4033e-04 - val_accuracy: 0.9169 - val_loss: 0.2753 - val_precition: 0.6667 - val_recall: 4.4366e-04
# Epoch 16/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 42s 25ms/step - accuracy: 0.9171 - loss: 0.2785 - precition: 0.5939 - recall: 6.1588e-04 - val_accuracy: 0.9169 - val_loss: 0.2750 - val_precition: 1.0000 - val_recall: 2.2183e-04
# Epoch 17/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9173 - loss: 0.2778 - precition: 0.1879 - recall: 1.1970e-04 - val_accuracy: 0.9169 - val_loss: 0.2751 - val_precition: 0.5000 - val_recall: 2.2183e-04
# Epoch 18/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9174 - loss: 0.2779 - precition: 0.3838 - recall: 3.1976e-04 - val_accuracy: 0.9169 - val_loss: 0.2753 - val_precition: 0.5000 - val_recall: 2.2183e-04
# Epoch 19/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 36s 24ms/step - accuracy: 0.9168 - loss: 0.2796 - precition: 0.1696 - recall: 1.0237e-04 - val_accuracy: 0.9169 - val_loss: 0.2758 - val_precition: 0.6667 - val_recall: 4.4366e-04
# Epoch 20/25
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 33s 25ms/step - accuracy: 0.9169 - loss: 0.2790 - precition: 0.0919 - recall: 6.9895e-05 - val_accuracy: 0.9169 - val_loss: 0.2752 - val_precition: 0.6667 - val_recall: 4.4366e-04
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
# --- INICIANDO FASE 2: FINE-TUNING ---
# Descongelando modelo base desde la capa 140.
# ✅ Modelo re-compilado para FASE 2 (Fine-Tuning).
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 2, 2, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ avg_pool                        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ head_dropout (Dropout)          │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc_pokemon (Dense)              │ (None, 18)             │        36,882 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,624,594 (90.12 MB)
#  Trainable params: 15,014,930 (57.28 MB)
#  Non-trainable params: 8,609,664 (32.84 MB)
# Epoch 20/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 72s 53ms/step - accuracy: 0.9073 - loss: 0.5420 - precition: 0.1154 - recall: 0.0176 - val_accuracy: 0.9162 - val_loss: 0.3815 - val_precition: 0.2967 - val_recall: 0.0060
# Epoch 21/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9138 - loss: 0.3103 - precition: 0.2017 - recall: 0.0113 - val_accuracy: 0.9165 - val_loss: 0.3176 - val_precition: 0.2500 - val_recall: 0.0027
# Epoch 22/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 52s 50ms/step - accuracy: 0.9167 - loss: 0.2910 - precition: 0.2862 - recall: 0.0045 - val_accuracy: 0.9166 - val_loss: 0.2940 - val_precition: 0.3636 - val_recall: 0.0053
# Epoch 23/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - accuracy: 0.9165 - loss: 0.2851 - precition: 0.3114 - recall: 0.0029 - val_accuracy: 0.9165 - val_loss: 0.2862 - val_precition: 0.3333 - val_recall: 0.0047
# Epoch 24/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 47ms/step - accuracy: 0.9170 - loss: 0.2814 - precition: 0.4251 - recall: 0.0042 - val_accuracy: 0.9168 - val_loss: 0.2841 - val_precition: 0.4565 - val_recall: 0.0047
# Epoch 25/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9171 - loss: 0.2787 - precition: 0.4930 - recall: 0.0056 - val_accuracy: 0.9167 - val_loss: 0.2818 - val_precition: 0.4127 - val_recall: 0.0058
# Epoch 26/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9166 - loss: 0.2772 - precition: 0.4280 - recall: 0.0044 - val_accuracy: 0.9169 - val_loss: 0.2770 - val_precition: 0.5152 - val_recall: 0.0075
# Epoch 27/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 47ms/step - accuracy: 0.9169 - loss: 0.2757 - precition: 0.5909 - recall: 0.0081 - val_accuracy: 0.9168 - val_loss: 0.2768 - val_precition: 0.4595 - val_recall: 0.0075
# Epoch 28/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 48s 46ms/step - accuracy: 0.9169 - loss: 0.2748 - precition: 0.5892 - recall: 0.0068 - val_accuracy: 0.9170 - val_loss: 0.2741 - val_precition: 0.5278 - val_recall: 0.0126
# Epoch 29/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9166 - loss: 0.2743 - precition: 0.4780 - recall: 0.0081 - val_accuracy: 0.9167 - val_loss: 0.2729 - val_precition: 0.4702 - val_recall: 0.0175
# Epoch 30/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9168 - loss: 0.2721 - precition: 0.5237 - recall: 0.0094 - val_accuracy: 0.9170 - val_loss: 0.2708 - val_precition: 0.5294 - val_recall: 0.0100
# Epoch 31/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 54s 54ms/step - accuracy: 0.9171 - loss: 0.2709 - precition: 0.6028 - recall: 0.0099 - val_accuracy: 0.9174 - val_loss: 0.2707 - val_precition: 0.6068 - val_recall: 0.0157
# Epoch 32/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 54s 54ms/step - accuracy: 0.9173 - loss: 0.2687 - precition: 0.5917 - recall: 0.0119 - val_accuracy: 0.9174 - val_loss: 0.2718 - val_precition: 0.6031 - val_recall: 0.0175
# Epoch 33/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9171 - loss: 0.2695 - precition: 0.5613 - recall: 0.0110 - val_accuracy: 0.9171 - val_loss: 0.2701 - val_precition: 0.5318 - val_recall: 0.0204
# Epoch 34/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 54s 54ms/step - accuracy: 0.9174 - loss: 0.2678 - precition: 0.5614 - recall: 0.0152 - val_accuracy: 0.9170 - val_loss: 0.2715 - val_precition: 0.5198 - val_recall: 0.0204
# Epoch 35/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9175 - loss: 0.2661 - precition: 0.5546 - recall: 0.0171 - val_accuracy: 0.9168 - val_loss: 0.2702 - val_precition: 0.4873 - val_recall: 0.0255
# Epoch 36/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9173 - loss: 0.2662 - precition: 0.5845 - recall: 0.0173 - val_accuracy: 0.9173 - val_loss: 0.2654 - val_precition: 0.5451 - val_recall: 0.0282
# Epoch 37/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 47ms/step - accuracy: 0.9172 - loss: 0.2644 - precition: 0.5677 - recall: 0.0175 - val_accuracy: 0.9171 - val_loss: 0.2661 - val_precition: 0.5420 - val_recall: 0.0157
# Epoch 38/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9169 - loss: 0.2644 - precition: 0.5264 - recall: 0.0157 - val_accuracy: 0.9172 - val_loss: 0.2655 - val_precition: 0.5392 - val_recall: 0.0260
# Epoch 39/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 54s 54ms/step - accuracy: 0.9177 - loss: 0.2620 - precition: 0.5664 - recall: 0.0201 - val_accuracy: 0.9177 - val_loss: 0.2651 - val_precition: 0.6316 - val_recall: 0.0240
# Epoch 40/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9172 - loss: 0.2619 - precition: 0.5624 - recall: 0.0193 - val_accuracy: 0.9173 - val_loss: 0.2626 - val_precition: 0.5598 - val_recall: 0.0228
# Epoch 41/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 55s 54ms/step - accuracy: 0.9174 - loss: 0.2610 - precition: 0.6011 - recall: 0.0224 - val_accuracy: 0.9175 - val_loss: 0.2621 - val_precition: 0.5563 - val_recall: 0.0362
# Epoch 42/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9179 - loss: 0.2592 - precition: 0.5930 - recall: 0.0262 - val_accuracy: 0.9177 - val_loss: 0.2605 - val_precition: 0.5907 - val_recall: 0.0311
# Epoch 43/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9173 - loss: 0.2583 - precition: 0.5767 - recall: 0.0260 - val_accuracy: 0.9176 - val_loss: 0.2616 - val_precition: 0.5744 - val_recall: 0.0308
# Epoch 44/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - accuracy: 0.9175 - loss: 0.2586 - precition: 0.5807 - recall: 0.0299 - val_accuracy: 0.9177 - val_loss: 0.2623 - val_precition: 0.5691 - val_recall: 0.0393
# Epoch 45/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9177 - loss: 0.2574 - precition: 0.6131 - recall: 0.0285 - val_accuracy: 0.9177 - val_loss: 0.2589 - val_precition: 0.5701 - val_recall: 0.0397
# Epoch 46/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9184 - loss: 0.2548 - precition: 0.5995 - recall: 0.0353 - val_accuracy: 0.9179 - val_loss: 0.2617 - val_precition: 0.5751 - val_recall: 0.0441
# Epoch 47/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - accuracy: 0.9183 - loss: 0.2541 - precition: 0.5984 - recall: 0.0363 - val_accuracy: 0.9178 - val_loss: 0.2627 - val_precition: 0.5918 - val_recall: 0.0350
# Epoch 48/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - accuracy: 0.9184 - loss: 0.2542 - precition: 0.5994 - recall: 0.0350 - val_accuracy: 0.9176 - val_loss: 0.2584 - val_precition: 0.5519 - val_recall: 0.0413
# Epoch 49/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 88s 54ms/step - accuracy: 0.9184 - loss: 0.2531 - precition: 0.6155 - recall: 0.0399 - val_accuracy: 0.9179 - val_loss: 0.2608 - val_precition: 0.5560 - val_recall: 0.0594
# Epoch 50/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9183 - loss: 0.2518 - precition: 0.6138 - recall: 0.0444 - val_accuracy: 0.9169 - val_loss: 0.2622 - val_precition: 0.5000 - val_recall: 0.0626
# Epoch 51/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9183 - loss: 0.2498 - precition: 0.6027 - recall: 0.0445 - val_accuracy: 0.9175 - val_loss: 0.2613 - val_precition: 0.5296 - val_recall: 0.0614
# Epoch 52/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 48s 46ms/step - accuracy: 0.9182 - loss: 0.2502 - precition: 0.5859 - recall: 0.0437 - val_accuracy: 0.9170 - val_loss: 0.2614 - val_precition: 0.5044 - val_recall: 0.0634
# Epoch 53/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 83s 47ms/step - accuracy: 0.9187 - loss: 0.2494 - precition: 0.6225 - recall: 0.0496 - val_accuracy: 0.9176 - val_loss: 0.2594 - val_precition: 0.5340 - val_recall: 0.0628
# Epoch 54/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9185 - loss: 0.2495 - precition: 0.6180 - recall: 0.0499 - val_accuracy: 0.9179 - val_loss: 0.2581 - val_precition: 0.5707 - val_recall: 0.0492
# Epoch 55/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 48s 46ms/step - accuracy: 0.9187 - loss: 0.2467 - precition: 0.6324 - recall: 0.0541 - val_accuracy: 0.9178 - val_loss: 0.2557 - val_precition: 0.5463 - val_recall: 0.0668
# Epoch 56/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9189 - loss: 0.2463 - precition: 0.6211 - recall: 0.0562 - val_accuracy: 0.9180 - val_loss: 0.2574 - val_precition: 0.5473 - val_recall: 0.0770
# Epoch 57/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9189 - loss: 0.2460 - precition: 0.6223 - recall: 0.0602 - val_accuracy: 0.9179 - val_loss: 0.2576 - val_precition: 0.5451 - val_recall: 0.0697
# Epoch 58/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9190 - loss: 0.2450 - precition: 0.6229 - recall: 0.0585 - val_accuracy: 0.9176 - val_loss: 0.2581 - val_precition: 0.5309 - val_recall: 0.0723
# Epoch 59/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9193 - loss: 0.2447 - precition: 0.6327 - recall: 0.0669 - val_accuracy: 0.9178 - val_loss: 0.2574 - val_precition: 0.5415 - val_recall: 0.0723
# Epoch 60/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9205 - loss: 0.2406 - precition: 0.6533 - recall: 0.0715 - val_accuracy: 0.9171 - val_loss: 0.2601 - val_precition: 0.5073 - val_recall: 0.0921
# Epoch 61/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9202 - loss: 0.2401 - precition: 0.6686 - recall: 0.0762 - val_accuracy: 0.9184 - val_loss: 0.2548 - val_precition: 0.5640 - val_recall: 0.0772
# Epoch 62/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9199 - loss: 0.2406 - precition: 0.6515 - recall: 0.0711 - val_accuracy: 0.9171 - val_loss: 0.2560 - val_precition: 0.5061 - val_recall: 0.0921
# Epoch 63/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9198 - loss: 0.2406 - precition: 0.6564 - recall: 0.0792 - val_accuracy: 0.9180 - val_loss: 0.2572 - val_precition: 0.5417 - val_recall: 0.0865
# Epoch 64/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9200 - loss: 0.2392 - precition: 0.6460 - recall: 0.0842 - val_accuracy: 0.9176 - val_loss: 0.2584 - val_precition: 0.5268 - val_recall: 0.0830
# Epoch 65/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9204 - loss: 0.2374 - precition: 0.6316 - recall: 0.0818 - val_accuracy: 0.9158 - val_loss: 0.2634 - val_precition: 0.4682 - val_recall: 0.0996
# Epoch 66/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9205 - loss: 0.2377 - precition: 0.6507 - recall: 0.0845 - val_accuracy: 0.9171 - val_loss: 0.2580 - val_precition: 0.5079 - val_recall: 0.0932
# Epoch 67/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 48s 46ms/step - accuracy: 0.9201 - loss: 0.2368 - precition: 0.6337 - recall: 0.0884 - val_accuracy: 0.9181 - val_loss: 0.2552 - val_precition: 0.5388 - val_recall: 0.1000
# Epoch 68/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9203 - loss: 0.2383 - precition: 0.6696 - recall: 0.0901 - val_accuracy: 0.9175 - val_loss: 0.2600 - val_precition: 0.5204 - val_recall: 0.0934
# Epoch 69/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9209 - loss: 0.2341 - precition: 0.6481 - recall: 0.0931 - val_accuracy: 0.9177 - val_loss: 0.2536 - val_precition: 0.5241 - val_recall: 0.1012
# Epoch 70/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 51s 49ms/step - accuracy: 0.9211 - loss: 0.2347 - precition: 0.6648 - recall: 0.1004 - val_accuracy: 0.9145 - val_loss: 0.2708 - val_precition: 0.4420 - val_recall: 0.1116
# Epoch 71/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9212 - loss: 0.2326 - precition: 0.6609 - recall: 0.1108 - val_accuracy: 0.9170 - val_loss: 0.2619 - val_precition: 0.5023 - val_recall: 0.1207
# Epoch 72/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9210 - loss: 0.2320 - precition: 0.6610 - recall: 0.1027 - val_accuracy: 0.9177 - val_loss: 0.2554 - val_precition: 0.5268 - val_recall: 0.0938
# Epoch 73/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 51s 50ms/step - accuracy: 0.9218 - loss: 0.2300 - precition: 0.6794 - recall: 0.1125 - val_accuracy: 0.9178 - val_loss: 0.2559 - val_precition: 0.5264 - val_recall: 0.1129
# Epoch 74/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9222 - loss: 0.2280 - precition: 0.6671 - recall: 0.1198 - val_accuracy: 0.9173 - val_loss: 0.2570 - val_precition: 0.5090 - val_recall: 0.1187
# Epoch 75/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 54s 54ms/step - accuracy: 0.9218 - loss: 0.2299 - precition: 0.6695 - recall: 0.1210 - val_accuracy: 0.9179 - val_loss: 0.2561 - val_precition: 0.5262 - val_recall: 0.1180
# Epoch 76/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9223 - loss: 0.2275 - precition: 0.6754 - recall: 0.1267 - val_accuracy: 0.9181 - val_loss: 0.2561 - val_precition: 0.5327 - val_recall: 0.1191
# Epoch 77/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 50s 48ms/step - accuracy: 0.9220 - loss: 0.2279 - precition: 0.6781 - recall: 0.1202 - val_accuracy: 0.9177 - val_loss: 0.2604 - val_precition: 0.5226 - val_recall: 0.1127
# Epoch 78/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - accuracy: 0.9229 - loss: 0.2257 - precition: 0.6933 - recall: 0.1346 - val_accuracy: 0.9175 - val_loss: 0.2590 - val_precition: 0.5161 - val_recall: 0.1171
# Epoch 79/100
# 754/754 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - accuracy: 0.9229 - loss: 0.2257 - precition: 0.6792 - recall: 0.1351 - val_accuracy: 0.9171 - val_loss: 0.2592 - val_precition: 0.5040 - val_recall: 0.1244
# Epoch 79: early stopping
# Restoring model weights from the end of the best epoch: 69.
# 🚀 ¡Entrenamiento completado (Fase 1 y 2)!

# %%
print("\nGenerando cuadrícula de imágenes aleatorias del set de entrenamiento...")

# Definir el tamaño de la cuadrícula
filas = 3
columnas = 3
num_imagenes = filas * columnas

# Crear la figura y los ejes para la cuadrícula
# figsize ajusta el tamaño total de la imagen
fig, axes = plt.subplots(filas, columnas, figsize=(10, 10))

# Obtener 9 índices aleatorios únicos del conjunto de entrenamiento
# Usamos `random.sample` para asegurar que no haya duplicados
try:
    indices_aleatorios = random.sample(range(len(X_train_paths)), k=num_imagenes)
except ValueError:
    print(f"Error: No tienes suficientes imágenes ({len(X_train_paths)}) para una cuadrícula de {num_imagenes}.")
    # En este caso, simplemente salimos o ajustamos num_imagenes
    indices_aleatorios = [] # Salir

if indices_aleatorios:
    # Aplanar el array de ejes (de 2D a 1D) para iterar fácilmente
    for i, ax in enumerate(axes.flat):
        # Obtener el índice aleatorio
        idx = indices_aleatorios[i]

        # Obtener la ruta de la imagen y la etiqueta
        img_path = X_train_paths[idx]
        label = y_train[idx]

        try:
            # Cargar la imagen desde la ruta
            img = mpimg.imread(img_path)

            # Mostrar la imagen en el eje (subplot)
            ax.imshow(img)

            # --- Formatear el título (etiqueta) ---
            # 'y_train' proviene de 'y_binarized', por lo que puede ser un array one-hot
            # (ej. [0, 1, 0, 0]) o un solo número.
            # Este código intenta manejar ambos casos.
            label_str = ""
            if isinstance(label, (np.ndarray, list)):
                # Si es one-hot, encontramos el índice del '1'
                if np.sum(label) == 1:
                    label_str = f"Clase: {np.argmax(label)}"
                else: # Si es otra cosa (ej. multi-label)
                    label_str = str(label)
            else: # Si es un solo número o string
                label_str = f"Clase: {label}"

            ax.set_title(label_str, fontsize=10)

            # Ocultar los ejes (ticks, labels, etc.)
            ax.axis('off')

        except FileNotFoundError:
            print(f"Error: No se pudo encontrar el archivo {img_path}")
            ax.set_title("Archivo no encontrado", fontsize=8)
            ax.axis('off')
        except Exception as e:
            print(f"Error al cargar {img_path}: {e}")
            ax.set_title("Error de carga", fontsize=8)
            ax.axis('off')

    # Ajustar el espaciado para que los títulos no se superpongan
    plt.tight_layout()

    # Guardar la figura en un archivo
    output_filename = "grid_imagenes_entrenamiento.png"
    plt.savefig(output_filename)
    print(f"Cuadrícula de imágenes guardada como: {output_filename}")

    plt.show()
else:
    print("No hay suficientes imágenes para generar la cuadrícula.")
# Out:
# Generando cuadrícula de imágenes aleatorias del set de entrenamiento...
# Error al cargar /content/pokemon1/Pokemon Images DB/Gliscor/Gliscor.png: not a PNG file
# Cuadrícula de imágenes guardada como: grid_imagenes_entrenamiento.png

# %%
history_combined = {}

# Concatenar las métricas de la fase 1 y la fase 2
history_combined['loss'] = history_fase1.history['loss'] + history_fase2.history['loss']
history_combined['val_loss'] = history_fase1.history['val_loss'] + history_fase2.history['val_loss']
history_combined['accuracy'] = history_fase1.history['accuracy'] + history_fase2.history['accuracy']
history_combined['val_accuracy'] = history_fase1.history['val_accuracy']

# --- Graficar ---

plt.figure(figsize=(12, 5))

# Graficar Pérdida (Loss)
plt.subplot(1, 2, 1)
plt.plot(history_combined['loss'], label='Pérdida de Entrenamiento')
plt.plot(history_combined['val_loss'], label='Pérdida de Validación')
plt.title('Pérdida (Loss) a través de las Épocas')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()

# Graficar Precisión (Accuracy)
plt.subplot(1, 2, 2)
plt.plot(history_combined['accuracy'], label='Precisión de Entrenamiento')
plt.plot(history_combined['val_accuracy'], label='Precisión de Validación')
plt.title('Precisión (Accuracy) a través de las Épocas')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2468022804.py in <cell line: 0>()
#       2
#       3 # Concatenar las métricas de la fase 1 y la fase 2
# ----> 4 history_combined['loss'] = history_fase1.history['loss'] + history_fase2.history['loss']
#       5 history_combined['val_loss'] = history_fase1.history['val_loss'] + history_fase2.history['val_loss']
#       6 history_combined['accuracy'] = history_fase1.history['accuracy'] + history_fase2.history['accuracy']
#
# NameError: name 'history_fase1' is not defined

# %%
# Matriz de confusion
plt.figure(figsize=(15, 15))
y_pred_probs = model.predict(val_ds)
y_pred_indices = np.argmax(y_pred_probs, axis=1)
y_true_indices = np.argmax(np.array(list(y_val)), axis=1)

cm = confusion_matrix(y_true_indices, y_pred_indices)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=classes,
            yticklabels=classes)

plt.title('Mapa de Confusión - ResNet-50 Pokémon', fontsize=16)
plt.ylabel('Etiqueta Real (True Label)', fontsize=12)
plt.xlabel('Etiqueta Predicha (Predicted Label)', fontsize=12)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1445385734.py in <cell line: 0>()
#       1 # Matriz de confusion
# ----> 2 plt.figure(figsize=(15, 15))
#       3 y_pred_probs = model.predict(val_ds)
#       4 y_pred_indices = np.argmax(y_pred_probs, axis=1)
#       5 y_true_indices = np.argmax(np.array(list(y_val)), axis=1)
#
# NameError: name 'plt' is not defined

# %%
# --- 1. Generar predicciones (usando el modelo 'sigmoid' entrenado) ---
y_pred_probs = model.predict(val_ds)

# --- 2. Convertir probabilidades a etiquetas ---
# 'sigmoid' nos da probabilidades (0.0 a 1.0) para cada clase.
# Decidimos que cualquier cosa por encima del 50% (0.5) es un "Sí".
y_pred = (y_pred_probs > 0.5).astype(int)

# --- 3. Generar el reporte ---
# 'y_val' son las etiquetas reales, 'y_pred' son las que dijo el modelo
# 'class_names' es tu lista de 18 nombres de Pokémon
print(classification_report(y_val, y_pred, target_names=classes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3556742003.py in <cell line: 0>()
#       1 # --- 1. Generar predicciones (usando el modelo 'sigmoid' entrenado) ---
# ----> 2 y_pred_probs = model.predict(val_ds)
#       3
#       4 # --- 2. Convertir probabilidades a etiquetas ---
#       5 # 'sigmoid' nos da probabilidades (0.0 a 1.0) para cada clase.
#
# NameError: name 'model' is not defined
